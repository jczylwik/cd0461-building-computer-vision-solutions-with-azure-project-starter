# %%
import io
import datetime
import pandas as pd
from PIL import Image
import requests
import io
import glob, os, sys, time, uuid

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline

from urllib.parse import urlparse
from io import BytesIO
from PIL import Image, ImageDraw

from video_indexer import VideoIndexer
from azure.cognitiveservices.vision.face import FaceClient
from azure.cognitiveservices.vision.face.models import TrainingStatusType
from msrest.authentication import CognitiveServicesCredentials
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient

# %% [markdown]
# ## Azure authentication
# Don't forget to `az login` in cmd!

# %%
keyVaultName = "cvprojectkeyvault"
KVUri = f"https://{keyVaultName}.vault.azure.net"

credential = DefaultAzureCredential()
client = SecretClient(vault_url=KVUri, credential=credential)

# %%
VIDEO_INDEXER_ACCOUNT_ID = client.get_secret("videoindexeraccountid2").value
VIDEO_INDEXER_SUBSCRIPTION_KEY = client.get_secret("videoindexersubscriptionkey2").value

# %%
CONFIG = {
    'SUBSCRIPTION_KEY': VIDEO_INDEXER_SUBSCRIPTION_KEY,
    'LOCATION': 'trial',
    'ACCOUNT_ID': VIDEO_INDEXER_ACCOUNT_ID
}

video_analysis = VideoIndexer(
    vi_subscription_key=CONFIG['SUBSCRIPTION_KEY'],
    vi_location=CONFIG['LOCATION'],
    vi_account_id=CONFIG['ACCOUNT_ID']
)

# %%
video_analysis.check_access_token()
# Out:
# Getting video indexer access token...
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File C:\JCZYLWI\MyPythonProjects\AI_Engineer_Nanodegree\venv\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File C:\JCZYLWI\MyPythonProjects\AI_Engineer_Nanodegree\venv\Lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...
